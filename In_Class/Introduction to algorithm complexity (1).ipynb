# %% [markdown]
# # Algorithm complexity
#
# <div class="alert alert-info"><b>Exercise 1</b>
#
# Write the code to compute the factorial of all the numbers from 1 to 100
#
# </div>
#
#
#
# <div class="alert alert-warning">
#
# You can use the function ```np.math.factorial()```.
#
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(100):
    print(np.math.factorial(i))
# Out:
# 1
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 6227020800
# 87178291200
# 1307674368000
# 20922789888000
# 355687428096000
# 6402373705728000
# 121645100408832000
# 2432902008176640000
# 51090942171709440000
# 1124000727777607680000
# 25852016738884976640000
# 620448401733239439360000
# 15511210043330985984000000
# 403291461126605635584000000
# 10888869450418352160768000000
# 304888344611713860501504000000
# 8841761993739701954543616000000
# 265252859812191058636308480000000
# 8222838654177922817725562880000000
# 263130836933693530167218012160000000
# 8683317618811886495518194401280000000
# 295232799039604140847618609643520000000
# 10333147966386144929666651337523200000000
# 371993326789901217467999448150835200000000
# 13763753091226345046315979581580902400000000
# 523022617466601111760007224100074291200000000
# 20397882081197443358640281739902897356800000000
# 815915283247897734345611269596115894272000000000
# ...

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 2</b>
#
# A sorting algorithm has a complexity equal to $\mathcal{O}(n log n)$ to sort a list of $n$ elements. If it uses 1 ms to sort 1000 items, how long will it take to sort 1000000?
# </div>

# %%
log = np.math.log(1000000)
print(1000000*log)
# Out:
# 13815510.557964273
# /var/folders/tq/vbr5qzv15js8_wmbmlg8s_6c0000gn/T/ipykernel_36861/2334095431.py:1: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   log = np.math.log(1000000)

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 3</b>
#
# What is the complexity $\mathcal{O}()$ of these algorithms?
#
# * $5+0.0001n^3 + 0.025n$
# * $500n + 100n^{1.5} + 50n log n$
# * $0.3n + 5n^{1.5} + 2.5 n^{1.75}$
# * $0.01 n log n + n (log n)^2$
# </div>

# %%
print("O(n^3)")
print("O(n^1.5)")
print("O(n^1.75)")
print("O(n(logn)^2)")

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 4</b>
#
# Two algorithms $A$ and $B$ have complexity $\mathcal{O}(0.1 n^2 log n)$ and $\mathcal{O}(2.5 n^2)$, respectively, for a problem of size $n$. If the problem you want to solve will always have size $n < 10^9$, which algorithm would you choose?
#
# </div>

# %%
A = 0.1 * 1000**2 * np.math.log(1000)
B = 2.5 * 1000**2
print(A, B)
# Out:
# 690775.5278982137 2500000.0
# /var/folders/tq/vbr5qzv15js8_wmbmlg8s_6c0000gn/T/ipykernel_36861/3954380464.py:1: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   A = 0.1 * 1000**2 * np.math.log(1000)

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 5</b>
#
# Calculate the total time complexity of these sample codes:
#
# </div>

# %%
def algorithm1():
    op1 # Complexity O(1)
    op2 # Complexity O(n)
    for i in range(0, n):
        op3 # Complexity O(n) 
    if cond:
        op4 # Complexity O(n) 
    else:
        op5 # Complexity O(n^2)

# %%
print("O(n^2)")

# %%
def algorithm2():
    for i in range(0,2*n):
        for j in range(0, n*n):
            op1 # Complexitat O(n)

# %%
print("O(n^4)")

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 6</b>
#
# Calculate the total space complexity of these sample codes:
#
# </div>

# %%
def add(x,y,z):  
    a = x + y + z
    return (a)

# %%
print("O(1)")

# %%
def sum_of_numbers(arr, n):
    sum=0
    for i in range(n):
        sum = sum + arr[i]
    return sum

# %%
print("O(1)")

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact*=i
    return fact
